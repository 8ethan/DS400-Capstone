# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import os

# %%
processed_dir = 'D:\\Notebooks\\DS400-Capstone\\main\\Processed_Network_dataset'
#data1 = pd.read_csv(processed_dir+'\\Network_dataset_1.csv')

# %%
sets = os.listdir(processed_dir)
full_data = pd.DataFrame()
for dataset in sets:
    cur = pd.read_csv(processed_dir+"\\"+dataset)
    full_data = pd.concat([cur, full_data], axis=0)

# %%
data = pd.concat([ full_data[full_data['label']==1].sample(n=250000), full_data[full_data['label']==0].sample(n=250000) ], axis=0)

# %%
len(data)
# Out:
# 500000

# %%
data.columns
# Out:
# Index(['ts', 'src_ip', 'src_port', 'dst_ip', 'dst_port', 'proto', 'service',
#        'duration', 'src_bytes', 'dst_bytes', 'conn_state', 'missed_bytes',
#        'src_pkts', 'src_ip_bytes', 'dst_pkts', 'dst_ip_bytes', 'dns_query',
#        'dns_qclass', 'dns_qtype', 'dns_rcode', 'dns_AA', 'dns_RD', 'dns_RA',
#        'dns_rejected', 'ssl_version', 'ssl_cipher', 'ssl_resumed',
#        'ssl_established', 'ssl_subject', 'ssl_issuer', 'http_trans_depth',
#        'http_method', 'http_uri', 'http_version', 'http_request_body_len',
#        'http_response_body_len', 'http_status_code', 'http_user_agent',
#        'http_orig_mime_types', 'http_resp_mime_types', 'weird_name',
#        'weird_addl', 'weird_notice', 'label', 'type'],
#       dtype='object')

# %%
val_counts = data['label'].value_counts()
diff = val_counts[1]-val_counts[0]

# %%
data = data.drop(data[data['label'] == 1.0].sample(n=(diff)).index)

# %%
data['label'].value_counts()
# Out:
# 1.0    250000
# 0.0    250000
# Name: label, dtype: int64

# %%
data.head(5)
# Out:
#                 ts        src_ip  src_port         dst_ip  dst_port proto  \
# 828560  1556078601  192.168.1.32   49569.0   192.168.1.79    1096.0   tcp
# 415430  1556249090  192.168.1.38   52142.0  192.168.1.184     443.0   tcp
# 167976  1556258563  192.168.1.38   45280.0  192.168.1.184     443.0   tcp
# 704517  1556227701  192.168.1.30   56408.0  192.168.1.184     443.0   tcp
# 67444   1556230482  192.168.1.31   41272.0  192.168.1.190      80.0   tcp
#
#        service   duration  src_bytes  dst_bytes  ... http_response_body_len  \
# 828560       -   0.000000        0.0        0.0  ...                    0.0
# 415430       -  60.675302        0.0        0.0  ...                    0.0
# 167976       -   0.000400        0.0        0.0  ...                    0.0
# 704517       -  66.901804        0.0        0.0  ...                    0.0
# 67444        -   0.000004        0.0        0.0  ...                    0.0
#
#         http_status_code  http_user_agent  http_orig_mime_types  \
# 828560               0.0                -                     -
# 415430               0.0                -                     -
# 167976               0.0                -                     -
# 704517               0.0                -                     -
# 67444                0.0                -                     -
#
#         http_resp_mime_types  weird_name weird_addl  weird_notice  label  \
# 828560                     -           -          -             -    1.0
# 415430                     -           -          -             -    1.0
# 167976                     -           -          -             -    1.0
# 704517                     -           -          -             -    1.0
# 67444                      -           -          -             -    1.0
#
#             type
# 828560  scanning
# 415430      ddos
# 167976      ddos
# 704517      ddos
# 67444       ddos
#
# [5 rows x 45 columns]

# %%
data['type'].value_counts()
# Out:
# normal        250000
# scanning       84623
# ddos           72782
# dos            39731
# xss            24684
# password       16018
# backdoor        5947
# injection       5348
# ransomware       857
# mitm              10
# Name: type, dtype: int64

# %%
data['service'][0]
# Out:
# '-'

# %%
data.replace(to_replace='-', value=np.nan, inplace=True)

# %%
# Drop columns that are defiantely not wanted
data.drop(['ts','src_ip','dst_ip','type'], axis=1, inplace=True)

# %%
plt.figure(figsize=(10,6))
sns.heatmap(data.isna())
# Out:
# <AxesSubplot: >

# %%
data.head(5)
# Out:
#         src_port  dst_port proto service   duration  src_bytes  dst_bytes  \
# 828560   49569.0    1096.0   tcp     NaN   0.000000        0.0        0.0
# 415430   52142.0     443.0   tcp     NaN  60.675302        0.0        0.0
# 167976   45280.0     443.0   tcp     NaN   0.000400        0.0        0.0
# 704517   56408.0     443.0   tcp     NaN  66.901804        0.0        0.0
# 67444    41272.0      80.0   tcp     NaN   0.000004        0.0        0.0
#
#        conn_state  missed_bytes  src_pkts  ...  http_request_body_len  \
# 828560         S0           0.0       1.0  ...                    0.0
# 415430         S3           0.0       3.0  ...                    0.0
# 167976         S1           0.0       2.0  ...                    0.0
# 704517         S3           0.0       3.0  ...                    0.0
# 67444          S1           0.0       2.0  ...                    0.0
#
#         http_response_body_len  http_status_code http_user_agent  \
# 828560                     0.0               0.0             NaN
# 415430                     0.0               0.0             NaN
# 167976                     0.0               0.0             NaN
# 704517                     0.0               0.0             NaN
# 67444                      0.0               0.0             NaN
#
#         http_orig_mime_types  http_resp_mime_types  weird_name weird_addl  \
# 828560                   NaN                   NaN         NaN        NaN
# 415430                   NaN                   NaN         NaN        NaN
# 167976                   NaN                   NaN         NaN        NaN
# 704517                   NaN                   NaN         NaN        NaN
# 67444                    NaN                   NaN         NaN        NaN
#
#        weird_notice label
# 828560          NaN   1.0
# 415430          NaN   1.0
# 167976          NaN   1.0
# 704517          NaN   1.0
# 67444           NaN   1.0
#
# [5 rows x 41 columns]

# %%
nulls = data.isna().sum()

# %%
bad_cols = []
for i in range(len(nulls)):
    if nulls[i] > 499000:
        bad_cols.append(nulls.index[i])        
bad_cols
# Out:
# ['ssl_version',
#  'ssl_cipher',
#  'ssl_resumed',
#  'ssl_established',
#  'ssl_subject',
#  'ssl_issuer',
#  'http_trans_depth',
#  'http_method',
#  'http_uri',
#  'http_version',
#  'http_user_agent',
#  'http_orig_mime_types',
#  'http_resp_mime_types',
#  'weird_name',
#  'weird_addl',
#  'weird_notice']

# %%
data.drop(bad_cols, axis=1, inplace=True)

# %%
data.head()
# Out:
#         src_port  dst_port proto service   duration  src_bytes  dst_bytes  \
# 828560   49569.0    1096.0   tcp     NaN   0.000000        0.0        0.0
# 415430   52142.0     443.0   tcp     NaN  60.675302        0.0        0.0
# 167976   45280.0     443.0   tcp     NaN   0.000400        0.0        0.0
# 704517   56408.0     443.0   tcp     NaN  66.901804        0.0        0.0
# 67444    41272.0      80.0   tcp     NaN   0.000004        0.0        0.0
#
#        conn_state  missed_bytes  src_pkts  ...  dns_qtype  dns_rcode  dns_AA  \
# 828560         S0           0.0       1.0  ...        0.0        0.0     NaN
# 415430         S3           0.0       3.0  ...        0.0        0.0     NaN
# 167976         S1           0.0       2.0  ...        0.0        0.0     NaN
# 704517         S3           0.0       3.0  ...        0.0        0.0     NaN
# 67444          S1           0.0       2.0  ...        0.0        0.0     NaN
#
#        dns_RD  dns_RA  dns_rejected  http_request_body_len  \
# 828560    NaN     NaN           NaN                    0.0
# 415430    NaN     NaN           NaN                    0.0
# 167976    NaN     NaN           NaN                    0.0
# 704517    NaN     NaN           NaN                    0.0
# 67444     NaN     NaN           NaN                    0.0
#
#        http_response_body_len http_status_code label
# 828560                    0.0              0.0   1.0
# 415430                    0.0              0.0   1.0
# 167976                    0.0              0.0   1.0
# 704517                    0.0              0.0   1.0
# 67444                     0.0              0.0   1.0
#
# [5 rows x 25 columns]

# %%
plt.figure(figsize=(10,6))
sns.heatmap(data.isna())
# Out:
# <AxesSubplot: >

# %%
data['dns_query'].value_counts()
# Out:
# a2z3kk2ebqzso7.iot.ap-southeast-2.amazonaws.com    6025
# testphp.vulnweb.com                                4174
# www.mqtt-dashboard.com                             3603
# https://192.168.1.184.hub                          3486
# https://192.168.1.184                              3472
#                                                    ...
# 207.202.70.207.in-addr.arpa                           1
# 157.184.148.239.in-addr.arpa                          1
# rns4.twnic.net.tw                                     1
# 115.206.115.119.in-addr.arpa                          1
# dns10.hichina.com                                     1
# Name: dns_query, Length: 10864, dtype: int64

# %%
data.drop('dns_query', axis=1, inplace=True)

# %%
data['dns_AA'].value_counts()
# Out:
# F    55250
# T     9899
# Name: dns_AA, dtype: int64

# %%
data['http_status_code'].value_counts()
# Out:
# 0.0      499663
# 302.0       217
# 200.0        84
# 206.0        28
# 400.0         4
# 404.0         2
# 403.0         1
# 304.0         1
# Name: http_status_code, dtype: int64

# %%
data['service'].value_counts()
# Out:
# dns                85297
# http               54503
# ssl                 5663
# ftp                  171
# ssl;smtp              92
# smtp;ssl              90
# imap;ssl              79
# dhcp                  21
# dce_rpc                6
# smtp                   4
# gssapi;smb;ntlm        4
# gssapi                 4
# smb;gssapi;ntlm        3
# ftp-data               3
# gssapi;ntlm;smb        3
# smb;gssapi             2
# smb                    2
# ssl;imap               2
# radius                 2
# pop3;ssl               1
# ssh                    1
# dce_rpc;ntlm           1
# imap                   1
# Name: service, dtype: int64

# %%
data['dst_port'].value_counts()
# Out:
# 80.0       88277
# 53.0       77576
# 443.0      48981
# 15600.0    15772
# 7878.0     15129
#            ...
# 60614.0        1
# 29571.0        1
# 22299.0        1
# 24238.0        1
# 54182.0        1
# Name: dst_port, Length: 32174, dtype: int64

# %%
# Need to categorize src_port and dst_port

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
onehot = OneHotEncoder(drop='first')
onehot_cats = ['proto','service','conn_state','dns_qclass','dns_qtype','dns_rcode','dns_AA','dns_RD','dns_RA','dns_rejected','http_status_code']

# %%
encoded = onehot.fit_transform(data[onehot_cats])

# %%
#pd.DataFrame(encoded)
